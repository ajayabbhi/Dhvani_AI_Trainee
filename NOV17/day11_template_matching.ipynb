# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
# Load images
big = cv2.imread("Search.jpg", 0)      # main image
template = cv2.imread("template.jpg", 0)  # small template



# Choose method
method = cv2.TM_CCOEFF_NORMED

# Apply template matching
result = cv2.matchTemplate(big, template, method)

# Get best location
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)

# For TM_CCOEFF_NORMED → best match = max_loc
top_left = max_loc # For TM_SQDIFF_NORMED → best match = min_loc

h, w = template.shape[::]

bottom_right = (top_left[0] + w, top_left[1] + h)

# Draw rectangle on the matched region
cv2.rectangle(output, top_left, bottom_right, (0, 255, 255), 7)

print("Match score:", max_val) #min_val for TM_SQDIFF_NORMED

plt.figure(figsize=(10,5))
plt.subplot(1, 1,1),plt.title('Detected Point'),plt.imshow(output , cmap='gray'),plt.axis('off')
plt.tight_layout()
# Out:
# Match score: 0.5207628607749939
